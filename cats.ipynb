# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !ls /content/drive/MyDrive
# Out:
#  16148_flip-flop1.gslides
# '2305802_Activity -1.pdf'
# '2305802_assignment 1-compressed.pdf'
# '2305802_B (1).Etc_assignment-1.pdf'
#  2305802_B.Etc_assignment-1.pdf
#  2305802_BIOM-04_Assignment1.pdf
# '2305802_biomed assignment-2 (1).pdf'
# '2305802_biomed assignment-2.pdf'
# '2305802_chemistry assignment.pdf'
#  2305802_cover-letters.pdf
#  2305802_DOS_Assignment-1.pdf
#  2305802_DOS_assignment-2.pdf
# '2305802_email writing (1).pdf'
# '2305802_email writing.pdf'
# '2305802_english test.pdf'
# '2305802_essay writing.pdf'
#  2305802_grammar.pdf
# '2305802_listening test.pdf'
#  2305802_memo_writing.pdf
#  2305802_OS_assignment.pdf
#  2305802_prog1.cpp
#  2305802_prog2.cpp
#  2305802_prog3.cpp
# '2305802_PROJECTION OF LINES NEW.pdf'
# '2305802_projection of planes (1).dwg'
# '2305802_projection of planes.dwg'
#  2305802_resume1.pdf
# '2305802_RituKumari (1).pdf'
# '2305802_RituKumari (2).pdf'
# '2305802_RituKumari (3).pdf'
#  2305802_RituKumari.pdf
#  2305802_ScLS_Assignment-2.pdf
# '2305802_sheet-6_projection of solids.pdf'
#  3c75427e-fd84-4606-a9cd-4a8ccdf20294_1744538092%20-%20600.00%20To%20Prarabdh%20Atrey%20on%20Google%20Pay.png
#  46bc4c3e-62fc-4880-bd00-0185988bba47_payment_confirmation_20250104-113319.png
#  AntiraggingAffidavitForm.pdf
#  Certificates
#  Classroom
# 'COA-L13-14-15-Addressing modes.gslides'
# 'COA L3.gslides'
# 'COA L4-L5.gslides'
# 'Colab Notebooks'
#  counter.gslides
# 'DSD_Unit 1_Lecture_01 (1).gslides'
# 'DSD_Unit 1_Lecture_01 (2).gslides'
# 'DSD_Unit 1_Lecture_01 (3).gslides'
# 'DSD_Unit 1_Lecture_01.gslides'
# 'DSD_Unit 1_Lecture_02 (1).gslides'
# 'DSD_Unit 1_Lecture_02.gslides'
# 'DSD_Unit 1_Lecture_03 (1).gslides'
# 'DSD_Unit 1_Lecture_03.gslides'
# 'DSD_Unit 1_Lecture_04 (1).gslides'
# 'DSD_Unit 1_Lecture_04.gslides'
# 'DSD_Unit 1_Lecture_05 (1).gslides'
# 'DSD_Unit 1_Lecture_05.gslides'
# 'DSD_Unit 2_Lecture_01 (1).gslides'
# 'DSD_Unit 2_Lecture_01 (2).gslides'
# 'DSD_Unit 2_Lecture_01.gslides'
# 'DSD_Unit 2_Lecture_02 (1).gslides'
# 'DSD_Unit 2_Lecture_02 (2).gslides'
# 'DSD_Unit 2_Lecture_02.gslides'
# 'DSD_Unit 2_Lecture_03 (1).gslides'
# 'DSD_Unit 2_Lecture_03 (2).gslides'
# 'DSD_Unit 2_Lecture_03.gslides'
# 'DSD_Unit 2_Lecture_04 (1).gslides'
# 'DSD_Unit 2_Lecture_04 (2).gslides'
# 'DSD_Unit 2_Lecture_04.gslides'
# 'DSD_Unit 2_Lecture_05 (1).gslides'
# 'DSD_Unit 2_Lecture_05 (2).gslides'
# 'DSD_Unit 2_Lecture_05.gslides'
# 'DSD_Unit 2_Lecture_06 (1).gslides'
# 'DSD_Unit 2_Lecture_06 (2).gslides'
# 'DSD_Unit 2_Lecture_06 (3).gslides'
# 'DSD_Unit 2_Lecture_06.gslides'
# 'DSD_Unit 2_Lecture_07 (1).gslides'
# 'DSD_Unit 2_Lecture_07.gslides'
# 'DSD_Unit 3_Lecture_01 (1).gslides'
# 'DSD_Unit 3_Lecture_01.gslides'
# 'DSD_Unit 3_Lecture_02 (1).gslides'
# 'DSD_Unit 3_Lecture_02.gslides'
# 'DSD_Unit 3_Lecture_03.gslides'
# 'DSD_Unit 3_Lecture_04 (1).gslides'
# 'DSD_Unit 3_Lecture_04.gslides'
# 'DSD_Unit 3_Lecture_05.gslides'
# 'DSD_Unit 3_Lecture_06.gslides'
# 'Economic Impact of Trade Tariff Wars on Domestic Industries and Consumers – The Indian Case.gslides'
# 'EVS PRESENTATION.pptx'
# 'EVS TABULATION.xlsx'
#  IMG-20231127-WA0055.jpg
#  IMG20231225164146.jpg
#  IMG-20240707-WA0032.jpg
#  IMG20240912171810.jpg
#  IMG-20241105-WA0132.jpg
#  IMG_20250413_152218.jpg
# 'Investigation on Carbon Sequestration and Zero Carbon Emission.docx'
# 'Investigation on Carbon Sequestration and Zero Carbon Emission.pdf'
#  Kzarshion_undertaking.pdf
# 'Lecture II.gdoc'
# 'mom_game dev 02-04-25.gdoc'
# 'mom_game dev 25-03-25.gdoc'
#  Report.gdoc
#  resume.pdf
# 'RITU KUMARI - Projection of Plane: AutoCAD.gdoc'
# 'Ritu Kumari - Report Writing.gdoc'
# 'Ritu_kumari_resume_2025 (1).pdf'
#  Ritu_kumari_resume_2025.pdf
#  Unit-2-Communication-DOS-SCR.gslides
# 'Unit III (Teaching Notes).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document.gdoc'

# %%
# !ls /content/drive/MyDrive/Cats_Dogs_dataset/
# Out:
# ls: cannot access '/content/drive/MyDrive/Cats_Dogs_dataset/': No such file or directory

# %%
dataset_path = "/content/drive/MyDrive"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
img_size = 128
batch_size = 32
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
print(ImageDataGenerator)
# Out:
# <class 'keras.src.legacy.preprocessing.image.ImageDataGenerator'>

# %%
train_generator = datagen.flow_from_directory(
    "/content/drive/MyDrive/Cats_Dogs_dataset",
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1108283292.py in <cell line: 0>()
# ----> 1 train_generator = datagen.flow_from_directory(
#       2     "/content/drive/MyDrive/Cats_Dogs_dataset",
#       3     target_size=(img_size, img_size),
#       4     batch_size=batch_size,
#       5     class_mode='categorical',
#
# NameError: name 'datagen' is not defined

# %%
val_generator = datagen.flow_from_directory(
    "/content/drive/MyDrive/Cats_Dogs_dataset",
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1614708369.py in <cell line: 0>()
# ----> 1 val_generator = datagen.flow_from_directory(
#       2     "/content/drive/MyDrive/Cats_Dogs_dataset",
#       3     target_size=(img_size, img_size),
#       4     batch_size=batch_size,
#       5     class_mode='categorical',
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     451         if not classes:
#     452             classes = []
# --> 453             for subdir in sorted(os.listdir(directory)):
#     454                 if os.path.isdir(os.path.join(directory, subdir)):
#     455                     classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Cats_Dogs_dataset'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
model = Sequential()
model.add(
    Conv2D(
        32,              # number of filters
        (3, 3),          # filter size
        activation='relu',
        input_shape=(128, 128, 3)
    )
)
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(2, activation='softmax'))


model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     7,372,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,392,578 (28.20 MB)
#  Trainable params: 7,392,578 (28.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2549622283.py in <cell line: 0>()
#       1 history = model.fit(
# ----> 2     train_generator,
#       3     validation_data=val_generator,
#       4     epochs=10
#       5 )
#
# NameError: name 'train_generator' is not defined

# %%
from google.colab import files
model.save("cat_dog_cnn.h5")

files.download("cat_dog_cnn.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
